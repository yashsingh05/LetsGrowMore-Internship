# %% [markdown]
# # Stock Market Prediction and Forecasting using Stacked LSTM.

# %% [markdown]
# ## Importing Libraries.

# %%
#import the warnings.
import warnings
warnings.filterwarnings("ignore")

# %%
#import the useful libraries.
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Loading Data

# %%
#read the data set of "StockMarketData" in inp.
inp= pd.read_csv("StockMarket.csv")

# %%
inp.head()
# Out:
#         Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  7/21/2010  122.1  123.00  121.05  121.10  121.55                658666
# 1  7/22/2010  120.3  122.00  120.25  120.75  120.90                293312
# 2  7/23/2010  121.8  121.95  120.25  120.35  120.65                281312
# 3  7/26/2010  120.1  121.00  117.10  117.10  117.60                658440
# 4  7/27/2010  117.6  119.50  112.00  118.80  118.65                586100
#
#    Turnover (Lacs)
# 0           803.56
# 1           355.17
# 2           340.31
# 3           780.01
# 4           694.98

# %%
inp.tail()
# Out:
#            Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  9/24/2018  233.55  239.20  230.75  234.00  233.30               3423509
# 2031  9/25/2018  233.30  236.75  232.00  236.25  236.10               2349368
# 2032  9/26/2018  240.00  240.00  232.50  235.00  234.25               2240909
# 2033  9/27/2018  234.55  236.80  231.10  233.80  233.25               5082859
# 2034  9/28/2018  234.05  235.95  230.20  233.50  233.75               3069914
#
#       Turnover (Lacs)
# 2030          7999.55
# 2031          5503.90
# 2032          5248.60
# 2033         11859.95
# 2034          7162.35

# %%
inp.shape
# Out:
# (2035, 8)

# %%
inp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
inp.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
inp.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
plt.figure(figsize=(15, 8))
plt.plot(inp['Open'],'g')
plt.title('Open Price', fontsize=30)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Price', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.plot(inp['Last'],'r')
plt.title('Last Price', fontsize=30)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.show()

# %% [markdown]
# ## Prediction of Stock on Closed Price.

# %%
training_set = inp.iloc[:, 1:2].values

# %%
training_set.shape
# Out:
# (2035, 1)

# %%
plt.figure(figsize=(15, 8))
plt.plot(training_set)
plt.title('Close Price', fontsize=30)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Closing Price', fontsize=20)
plt.show()

# %% [markdown]
# ## Feature Scaling for optimal data performance.

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(np.array(training_set).reshape(-1,1))
training_set_scaled.shape
# Out:
# (2035, 1)

# %%
X_train = []
y_train = []
for i in range(60, 2035):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# ## Building the LSTM.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 8s 43ms/step - loss: 0.0093
# Epoch 2/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0033
# Epoch 3/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0029
# Epoch 4/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0027
# Epoch 5/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0029
# Epoch 6/100
# 62/62 [==============================] - 2s 40ms/step - loss: 0.0025
# Epoch 7/100
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0026
# Epoch 8/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0024
# Epoch 9/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0021
# Epoch 10/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0021
# Epoch 11/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0019
# Epoch 12/100
# 62/62 [==============================] - 3s 40ms/step - loss: 0.0017
# Epoch 13/100
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0017
# Epoch 14/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0017
# Epoch 15/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0021
# Epoch 16/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0018
# Epoch 17/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0015
# Epoch 18/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0015
# Epoch 19/100
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0018
# Epoch 20/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0014
# Epoch 21/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0017
# Epoch 22/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0014
# Epoch 23/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0012
# Epoch 24/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0013
# Epoch 25/100
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0013
# Epoch 26/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0014
# Epoch 27/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0013
# Epoch 28/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0014
# Epoch 29/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0014
# Epoch 30/100
# 62/62 [==============================] - 3s 40ms/step - loss: 0.0013
# Epoch 31/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0011
# Epoch 32/100
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0011
# Epoch 33/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0012
# Epoch 34/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0011
# Epoch 35/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0011
# Epoch 36/100
# 62/62 [==============================] - 3s 43ms/step - loss: 0.0012
# Epoch 37/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0012
# Epoch 38/100
# 62/62 [==============================] - 3s 45ms/step - loss: 0.0012
# Epoch 39/100
# 62/62 [==============================] - 3s 42ms/step - loss: 0.0010
# Epoch 40/100
# 62/62 [==============================] - 3s 44ms/step - loss: 9.8964e-04
# Epoch 41/100
# 62/62 [==============================] - 3s 43ms/step - loss: 9.1938e-04
# Epoch 42/100
# 62/62 [==============================] - 3s 43ms/step - loss: 9.1187e-04
# Epoch 43/100
# 62/62 [==============================] - 3s 47ms/step - loss: 9.5560e-04
# Epoch 44/100
# 62/62 [==============================] - 3s 44ms/step - loss: 0.0010
# Epoch 45/100
# 62/62 [==============================] - 3s 41ms/step - loss: 9.6768e-04
# Epoch 46/100
# 62/62 [==============================] - 3s 41ms/step - loss: 9.9811e-04
# Epoch 47/100
# 62/62 [==============================] - 2s 40ms/step - loss: 9.8453e-04
# Epoch 48/100
# 62/62 [==============================] - 3s 40ms/step - loss: 9.7707e-04
# Epoch 49/100
# 62/62 [==============================] - 3s 40ms/step - loss: 0.0010
# Epoch 50/100
# 62/62 [==============================] - 3s 43ms/step - loss: 9.0272e-04
# Epoch 51/100
# 62/62 [==============================] - 3s 41ms/step - loss: 0.0010
# Epoch 52/100
# 62/62 [==============================] - 3s 41ms/step - loss: 8.4627e-04
# Epoch 53/100
# 62/62 [==============================] - 2s 40ms/step - loss: 8.8560e-04
# Epoch 54/100
# 62/62 [==============================] - 2s 40ms/step - loss: 8.2925e-04
# Epoch 55/100
# 62/62 [==============================] - 3s 41ms/step - loss: 8.3265e-04
# Epoch 56/100
# 62/62 [==============================] - 3s 42ms/step - loss: 8.7604e-04
# Epoch 57/100
# 62/62 [==============================] - 3s 41ms/step - loss: 8.5693e-04
# Epoch 58/100
# 62/62 [==============================] - 2s 40ms/step - loss: 8.4352e-04
# Epoch 59/100
# 62/62 [==============================] - 2s 40ms/step - loss: 8.3450e-04
# Epoch 60/100
# 62/62 [==============================] - 3s 42ms/step - loss: 8.6391e-04
# Epoch 61/100
# 62/62 [==============================] - 3s 43ms/step - loss: 8.0008e-04
# Epoch 62/100
# 62/62 [==============================] - 3s 48ms/step - loss: 8.7243e-04
# Epoch 63/100
# 62/62 [==============================] - 3s 45ms/step - loss: 7.8884e-04
# Epoch 64/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.7923e-04
# Epoch 65/100
# 62/62 [==============================] - 3s 42ms/step - loss: 7.4016e-04
# Epoch 66/100
# 62/62 [==============================] - 3s 43ms/step - loss: 6.8459e-04
# Epoch 67/100
# 62/62 [==============================] - 3s 42ms/step - loss: 8.4085e-04
# Epoch 68/100
# 62/62 [==============================] - 3s 46ms/step - loss: 7.4024e-04
# Epoch 69/100
# 62/62 [==============================] - 2s 40ms/step - loss: 8.1330e-04
# Epoch 70/100
# 62/62 [==============================] - 3s 42ms/step - loss: 8.2162e-04
# Epoch 71/100
# 62/62 [==============================] - 3s 44ms/step - loss: 8.0515e-04
# Epoch 72/100
# 62/62 [==============================] - 3s 43ms/step - loss: 6.7562e-04
# Epoch 73/100
# 62/62 [==============================] - 3s 40ms/step - loss: 8.4649e-04
# Epoch 74/100
# 62/62 [==============================] - 3s 44ms/step - loss: 6.2564e-04
# Epoch 75/100
# 62/62 [==============================] - 3s 44ms/step - loss: 7.3409e-04
# Epoch 76/100
# 62/62 [==============================] - 3s 43ms/step - loss: 6.8055e-04
# Epoch 77/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.5516e-04
# Epoch 78/100
# 62/62 [==============================] - 3s 41ms/step - loss: 9.0757e-04
# Epoch 79/100
# 62/62 [==============================] - 2s 40ms/step - loss: 8.2556e-04
# Epoch 80/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.7097e-04
# Epoch 81/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.4364e-04
# Epoch 82/100
# 62/62 [==============================] - 3s 43ms/step - loss: 6.5870e-04
# Epoch 83/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.6968e-04
# Epoch 84/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.3403e-04
# Epoch 85/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.8739e-04
# Epoch 86/100
# 62/62 [==============================] - 3s 43ms/step - loss: 6.5555e-04
# Epoch 87/100
# 62/62 [==============================] - 3s 43ms/step - loss: 6.5755e-04
# Epoch 88/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.8295e-04
# Epoch 89/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.1135e-04
# Epoch 90/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.6644e-04
# Epoch 91/100
# 62/62 [==============================] - 3s 41ms/step - loss: 8.2501e-04
# Epoch 92/100
# 62/62 [==============================] - 3s 42ms/step - loss: 7.0996e-04
# Epoch 93/100
# 62/62 [==============================] - 3s 42ms/step - loss: 7.1426e-04
# Epoch 94/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.2861e-04
# Epoch 95/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.5888e-04
# Epoch 96/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.8159e-04
# Epoch 97/100
# 62/62 [==============================] - 3s 42ms/step - loss: 6.0090e-04
# Epoch 98/100
# 62/62 [==============================] - 3s 41ms/step - loss: 7.3230e-04
# Epoch 99/100
# 62/62 [==============================] - 3s 43ms/step - loss: 6.9187e-04
# Epoch 100/100
# 62/62 [==============================] - 3s 41ms/step - loss: 6.8482e-04

# %% [markdown]
# ## Predicting Future Stock using the Test Set.

# %%
df = pd.read_csv('testdata.csv') 
real_stock_price = df.iloc[:, 1:2].values

# %%
df.shape
# Out:
# (16, 8)

# %%
dataset_total = pd.concat((inp['Open'], df['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(df) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 76):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# ## Plotting the Results

# %%
plt.figure(figsize=(15, 8))
plt.plot(real_stock_price, color = 'red', label = 'Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted Stock Price')
plt.title('Stock Price Prediction', fontsize=30)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Stock Price', fontsize=20)
plt.legend()
plt.show()
